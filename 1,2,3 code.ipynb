# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("/content/DigitalDesignCSV.csv")

# Display the first five rows of the DataFrame
print("First five rows:")
print(df.head())

# Display the last five rows of the DataFrame
print("\nLast five rows:")
print(df.tail())
# Out:
# First five rows:
#      mid   Q1    Q2   HW1    HW2    end  Final Grade
# 0   90.0  100  40.0  70.0  42.86  93.75        86.56
# 1  100.0  100  65.0  85.0  57.14  73.75        86.31
# 2   92.5  100  60.0  80.0  42.86  83.75        85.56
# 3   97.5  100  40.0  85.0  76.19  70.00        83.75
# 4   70.0   95  75.0  85.0  38.09  95.00        80.75
#
# Last five rows:
#       mid  Q1    Q2   HW1    HW2  end  Final Grade
# 158  10.0  85  67.5  20.0   4.05  0.0         9.63
# 159   0.0   0  57.5  60.0  33.33  0.0         7.63
# 160   7.5   0   0.0   0.0   0.00  0.0         3.00
# 161   0.0   0   0.0   0.0   0.00  0.0         0.00
# 162   0.0   0   0.0   0.0   0.00  0.0         0.00

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("/content/DigitalDesignCSV.csv")

# Select only the numerical columns for correlation analysis
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Generate the correlation matrix
correlation_matrix = numerical_df.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numerical Columns")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file into a pandas DataFrame
df = pd.read_csv("/content/DigitalDesignCSV.csv")

# Plotting the pairplot
sns.pairplot(df)
plt.title("Pairplot of Features")
plt.show()
